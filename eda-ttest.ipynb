# %%
# %load_ext rpy2.ipython
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline  
from matplotlib import rcParams
rcParams['figure.figsize'] = (16, 100)

import warnings
from rpy2.rinterface import RRuntimeWarning
warnings.filterwarnings("ignore") # Ignore all warnings
# warnings.filterwarnings("ignore", category=RRuntimeWarning) # Show some warnings

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, HTML
# Out:
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %%R
#
# require('tidyverse')

# %%
df_amazon_intonations = pd.read_csv('../code/pitch_data/amazonfinds_intonations.csv')
df_amazon_intonations
# Out:
#                            file_name  intonations   duration  \
# 0   7236516655826750725_pitch_values            9  12.629093
# 1   7310344854129642757_pitch_values          153  82.376032
# 2   7185585185465879854_pitch_values           54  35.616848
# 3   7171239119006387502_pitch_values           11  18.062562
# 4   7254545022639426822_pitch_values           68  47.554807
# ..                               ...          ...        ...
# 95  7021521007458503942_pitch_values           22  17.461746
# 96  7158836355827617029_pitch_values           24  26.839705
# 97  7017066328842358021_pitch_values           24  19.133583
# 98  7217975957972356357_pitch_values            7  14.640522
# 99  7143333264667757870_pitch_values           29  18.402154
#
#     intonation_per_15
# 0           10.689604
# 1           27.860046
# 2           22.742046
# 3            9.134917
# 4           21.448936
# ..                ...
# 95          18.898454
# 96          13.412964
# ...

# %%
df_grwm_intonations = pd.read_csv('../code/pitch_data/grwm/grwm_intonations.csv')
df_grwm_intonations
# Out:
#                            file_name  intonations    duration  \
# 0   7267135268262530305_pitch_values          125  106.669909
# 1   7202674344118537478_pitch_values           40  176.233991
# 2   7374159222956756230_pitch_values           26   43.662562
# 3   7198124383557143851_pitch_values           67   86.268277
# 4   7317017754874285317_pitch_values           95  158.601338
# ..                               ...          ...         ...
# 78  7341417470663724330_pitch_values           57  179.656032
# 79  7389311347323915566_pitch_values          184  287.411134
# 80  7371388808509689134_pitch_values           17  195.538481
# 81  7390798775846980910_pitch_values           59  146.793991
# 82  7358179822432111918_pitch_values          170  156.407052
#
#     intonation_per_15
# 0           17.577591
# 1            3.404565
# 2            8.932137
# 3           11.649705
# 4            8.984792
# ..                ...
# 78           4.759094
# 79           9.602968
# ...

# %%
df_bookrec_intonations = pd.read_csv('../code/pitch_data/bookrecs2/bookrecs_intonations.csv')
df_bookrec_intonations
# Out:
#                            file_name  intonations    duration  \
# 0   7306201830168481054_pitch_values           82  150.372766
# 1   7320782185550679338_pitch_values           59  199.561338
# 2   7288699360202820870_pitch_values           49   91.623379
# 3   7319647306595257642_pitch_values            4   15.476440
# 4   7376083784275332398_pitch_values           50   89.820930
# ..                               ...          ...         ...
# 70  7394558056274709803_pitch_values           31   53.876440
# 71  7278439753203207467_pitch_values            2   76.028277
# 72  7394604979799002399_pitch_values          220  437.850317
# 73  7363749993758330154_pitch_values           60   44.132766
# 74  7370458729134722350_pitch_values           55  111.319705
#
#     intonation_per_15
# 0            8.179673
# 1            4.434727
# 2            8.021970
# 3            3.876861
# 4            8.349947
# ..                ...
# 70           8.630860
# 71           0.394590
# ...

# %%
df_storytime_intonations = pd.read_csv('../code/pitch_data/storytime/storytime_intonations.csv')
df_storytime_intonations
# Out:
#                            file_name  intonations    duration  \
# 0   7278063994366381358_pitch_values           33   47.920522
# 1   7207635437840600366_pitch_values           56  169.886236
# 2   7357865762192821550_pitch_values           52   75.976032
# 3   7343014651367525675_pitch_values          178  237.073175
# 4   7187992844739579182_pitch_values           86  137.233175
# ..                               ...          ...         ...
# 58  7269864676710763819_pitch_values           91  114.428277
# 59  7003446750191127814_pitch_values          120   56.096848
# 60  7211504104420543746_pitch_values          190  165.288685
# 61  7292858237857189162_pitch_values           84  180.178481
# 62  7336318763299523882_pitch_values          100   95.750726
#
#     intonation_per_15
# 0           10.329604
# 1            4.944485
# 2           10.266396
# 3           11.262345
# 4            9.400059
# ..                ...
# 58          11.928870
# 59          32.087364
# ...

# %%
# %%R -i df_amazon_intonations -i df_grwm_intonations -i df_bookrec_intonations -i df_storytime_intonations
#
# df_amazon <- df_amazon_intonations
# df_grwm <- df_grwm_intonations
# df_bookrec <- df_bookrec_intonations
# df_storytime <- df_storytime_intonations

# %%
# %%R
#
# head(df_amazon)
# Out:
#                          file_name intonations duration intonation_per_15
# 0 7236516655826750725_pitch_values           9 12.62909         10.689604
# 1 7310344854129642757_pitch_values         153 82.37603         27.860046
# 2 7185585185465879854_pitch_values          54 35.61685         22.742046
# 3 7171239119006387502_pitch_values          11 18.06256          9.134917
# 4 7254545022639426822_pitch_values          68 47.55481
#          21.448936
# 5 7254410849408797957_pitch_values          87 50.40215         25.891750

# %%
# %%R
#
# t.test(df_amazon$intonation_per_15, df_grwm$intonation_per_15, paired=FALSE)
# Out:
# 	Welch Two Sample t-test
#
# data:  df_amazon$intonation_per_15 and df_grwm$intonation_per_15
# t = 9.0024, df = 178.75, p-value = 3.238e-16
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  6.128132 9.568949
# sample estimates:
# mean of x mean of y
# 16.259331  8.410791

# %%
# %%R
#
# t.test(df_amazon$intonation_per_15, df_bookrec$intonation_per_15, paired=FALSE)
# Out:
# 	Welch Two Sample t-test
#
# data:  df_amazon$intonation_per_15 and df_bookrec$intonation_per_15
# t = 9.3146, df = 173, p-value < 2.2e-16
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#   6.58374 10.12417
# sample estimates:
# mean of x mean of y
# 16.259331  7.905374

# %%
# %%R
#
# t.test(df_amazon$intonation_per_15, df_storytime$intonation_per_15, paired=FALSE)
# Out:
# 	Welch Two Sample t-test
#
# data:  df_amazon$intonation_per_15 and df_storytime$intonation_per_15
# t = 5.2304, df = 154.37, p-value = 5.427e-07
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  3.073190 6.803463
# sample estimates:
# mean of x mean of y
#  16.25933  11.32100

# %%
# %%R
#
# # give me a violin chart of the three datasets
# ggplot() +
#     geom_violin(data=df_amazon, aes(x='amazon', y=intonation_per_15), fill='blue') +
#     geom_violin(data=df_grwm, aes(x='grwm', y=intonation_per_15), fill='red') +
#     geom_violin(data=df_bookrec, aes(x='bookrec', y=intonation_per_15), fill='green') +
#     geom_violin(data=df_storytime, aes(x='storytime', y=intonation_per_15), fill='yellow') +
#     theme_minimal()
