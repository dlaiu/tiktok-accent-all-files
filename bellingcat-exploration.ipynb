# %%
# !pip install tiktok-hashtag-analysis
# Out:
# ...
#   Obtaining dependency information for tiktok-hashtag-analysis from https://files.pythonhosted.org/packages/2b/8d/1249b3c68e1b174976e4f19cccd171dc35f2eb28d0e7c44a41bd363ad8da/tiktok_hashtag_analysis-2.0.3-py3-none-any.whl.metadata
# ...
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip

# %%
# !tiktok-hashtag-analysis amazonfinds --download --output-dir bellingcat-tool
# Out:
# 2024-06-27 17:45:37 INFO | Hashtags to scrape: ['amazonfinds']
# 2024-06-27 17:45:37 INFO | Writing data to directory: /Users/darryl/Documents/CJS/thesis/code/bellingcat-tool
# 2024-06-27 17:45:42 WARNING | Encountered error None -> TikTok returned an empty response when fetching data, retrying in headed mode
# 2024-06-27 17:46:07 INFO | Scraped 912 new posts containing the hashtag 'amazonfinds', with 0 posts previously scraped
# 2024-06-27 17:46:07 INFO | Downloading image galleries for hashtag amazonfinds
# 2024-06-27 17:46:58 INFO | Downloading media for hashtag amazonfinds
# WARNING: [TikTok] Expecting value in '': line 1 column 1 (char 0). Retrying... (attempt 1 of 4)
# WARNING: [TikTok] Expecting value in '': line 1 column 1 (char 0). Retrying... (attempt 2 of 4)
# WARNING: [TikTok] Expecting value in '': line 1 column 1 (char 0). Retrying... (attempt 3 of 4)
# ...

# %%
# !tiktok-hashtag-analysis fyp --output-dir bellingcat-tool
# Out:
# 2024-06-25 01:05:04 INFO | Hashtags to scrape: ['fyp']
# 2024-06-25 01:05:04 INFO | Writing data to directory: /Users/darryl/Documents/CJS/thesis/code/bellingcat-tool
# 2024-06-25 01:05:09 WARNING | Encountered error None -> TikTok returned an empty response when fetching data, retrying in headed mode
# 2024-06-25 01:05:52 INFO | Scraped 888 new posts containing the hashtag 'fyp', with 0 posts previously scraped

# %%
# !tiktok-hashtag-analysis fyp --download --output-dir bellingcat-tool
# Out:
# 2024-06-25 01:06:50 INFO | Hashtags to scrape: ['fyp']
# 2024-06-25 01:06:50 INFO | Writing data to directory: /Users/darryl/Documents/CJS/thesis/code/bellingcat-tool
# 2024-06-25 01:06:55 WARNING | Encountered error None -> TikTok returned an empty response when fetching data, retrying in headed mode
# 2024-06-25 01:07:18 INFO | Scraped 0 new posts containing the hashtag 'fyp', with 888 posts previously scraped
# 2024-06-25 01:07:18 INFO | Downloading image galleries for hashtag fyp
# 2024-06-25 01:07:25 INFO | Downloading media for hashtag fyp
# WARNING: [TikTok] Expecting value in '': line 1 column 1 (char 0). Retrying... (attempt 1 of 4)
# WARNING: [TikTok] Expecting value in '': line 1 column 1 (char 0). Retrying... (attempt 2 of 4)
# WARNING: [TikTok] Expecting value in '': line 1 column 1 (char 0). Retrying... (attempt 3 of 4)
# ...

# %%
import glob

# %%
tiktoks = glob.glob('bellingcat-tool/fyp/media/*.mp4')
len(tiktoks)
# Out:
# 884

# %%
import pandas as pd

# %%
#convert json to pandas dataframe
df = pd.read_json('bellingcat-tool/amazonfinds/posts.json')
df
# Out:
#     AIGCDescription BAInfo  adAuthorization  adLabelVersion  aigcLabelType  \
# 0                                     False               0              0
# 1                                     False               0              0
# 2                                     False               0              0
# 3                                     False               0              0
# 4                                      True               0              0
# ..              ...    ...              ...             ...            ...
# 910                                   False               0              0
# 911                                   False               0              0
# 912                                   False               0              0
# 913                                   False               0              0
# 914                                   False               0              0
#
#                                                 author  \
# ...

# %%
# !tiktok-hashtag-analysis amazonfinds --number 20 --table --output-dir bellingcat-tool/co-occuring_hashtags
# Out:
# 2024-05-22 16:16:18 INFO | Hashtags to scrape: ['amazonfinds']
# 2024-05-22 16:16:18 INFO | Writing data to directory: /Users/darryl/Documents/CJS/thesis/code/bellingcat-tool/co-occuring_hashtags
# 2024-05-22 16:16:24 WARNING | Encountered error None -> TikTok returned an empty response when fetching data, retrying in headed mode
# 2024-05-22 16:16:49 INFO | Scraped 918 new posts containing the hashtag 'amazonfinds', with 0 posts previously scraped
#
# Co-occurring hashtags for #amazonfinds posts
# Rank     Hashtag                        Occurrences     Frequency
# 0        amazonfinds                    918             1.0000
# 1        amazon                         300             0.3268
# 2        amazonmusthaves                280             0.3050
# 3        fyp                            253             0.2756
# 4        tiktokmademebuyit              136             0.1481
# 5        foryou                         90              0.0980
# ...

# %%
# !tiktok-hashtag-analysis amazonfinds --number 20 --plot --output-dir bellingcat-tool/co-occuring_hashtags
# Out:
# 2024-05-22 16:17:51 INFO | Hashtags to scrape: ['amazonfinds']
# 2024-05-22 16:17:51 INFO | Writing data to directory: /Users/darryl/Documents/CJS/thesis/code/bellingcat-tool/co-occuring_hashtags
# 2024-05-22 16:17:56 WARNING | Encountered error None -> TikTok returned an empty response when fetching data, retrying in headed mode
# 2024-05-22 16:18:21 INFO | Scraped 0 new posts containing the hashtag 'amazonfinds', with 918 posts previously scraped
# 2024-05-22 16:18:22 INFO | Plot saved to file: /Users/darryl/Documents/CJS/thesis/code/bellingcat-tool/co-occuring_hashtags/amazonfinds/plots/amazonfinds__2024_05_22_16_18_21.png

# %%
len(df)
# Out:
# 918

# %%
# !tiktok-hashtag-analysis amazonfinds
# Out:
# 2024-05-29 20:01:24 INFO | Hashtags to scrape: ['amazonfinds']
# 2024-05-29 20:01:24 INFO | Writing data to directory: /Users/darryl/tiktok_hashtag_data
# 2024-05-29 20:01:29 WARNING | Encountered error None -> TikTok returned an empty response when fetching data, retrying in headed mode
# 2024-05-29 20:01:56 INFO | Scraped 1 new posts containing the hashtag 'amazonfinds', with 918 posts previously scraped
